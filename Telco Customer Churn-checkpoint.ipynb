# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"D:\DataMites\YS-self initiated projects\Telco_Customer_Churn\Telco-Customer-Churn.csv")

# %%
# Data preview 
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# Checking for missing values
print(df.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Total Churn Count
churn_count = df['Churn'].value_counts()
print(churn_count)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Plot total churn
plt.figure(figsize=(6,4))
sns.countplot(x='Churn', data=df, palette='Set2')
plt.title("Total Churn Count")
plt.show()
# Out:
# C:\Users\YASIN\AppData\Local\Temp\ipykernel_10424\2150020183.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='Set2')

# %%
#Churn by Contract Type
contract_churn = df.groupby('Contract')['Churn'].value_counts().unstack()
print(contract_churn)
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
# Plot churn by contract type
contract_churn.plot(kind='bar', stacked=True, figsize=(8,5), color=['skyblue','red'])
plt.title("Churn by Contract Type")
plt.ylabel("Number of Customers")
plt.show()

# %%
# Churn by Gender
gender_churn = df.groupby('gender')['Churn'].value_counts().unstack()
print(gender_churn)
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %%
# Plot churn by gender
gender_churn.plot(kind='bar', stacked=True, figsize=(6,4), color=['lightgreen','orange'])
plt.title("Churn by Gender")
plt.ylabel("Number of Customers")
plt.show()

# %%
# Churn by Internet Service
internet_churn = df.groupby('InternetService')['Churn'].value_counts().unstack()
print(internet_churn)
# Out:
# Churn              No   Yes
# InternetService
# DSL              1962   459
# Fiber optic      1799  1297
# No               1413   113

# %%
# Plot churn by Internet Service
internet_churn.plot(kind='bar', stacked=True, figsize=(8,5), color=['lightblue','pink'])
plt.title("Churn by Internet Service")
plt.ylabel("Number of Customers")
plt.show()

# %%
# Average Monthly Charges for Churned vs Retained Customers
avg_monthly_charges = df.groupby('Churn')['MonthlyCharges'].mean()
print(avg_monthly_charges)
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df, palette='Set1')
plt.title("Monthly Charges Distribution by Churn")
plt.ylabel("Monthly Charges")
plt.show()
# Out:
# C:\Users\YASIN\AppData\Local\Temp\ipykernel_10424\576982377.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='MonthlyCharges', data=df, palette='Set1')
